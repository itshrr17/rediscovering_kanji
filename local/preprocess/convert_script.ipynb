# %%
from svg2png import convert_svg2png

# process radicals

radicals_in = '../data_raw/radical-characters'
radicals_out = '../data_cleaned/radicals_cleaned'

convert_svg2png(radicals_in, radicals_out)
# Out:
# Starting to process ../data_raw/radical-characters -> ../data_cleaned/radicals_cleaned
# 100%|██████████| 247/247 [00:01<00:00, 236.55it/s]

# %%
# process jouyou kanji

jouyou_in = '../data_cleaned/jouyou_kanji'
jouyou_out = '../data_cleaned/jouyou_kanji_grayscale'

convert_svg2png(jouyou_in, jouyou_out)
# Out:
# Starting to process ../data_cleaned/jouyou_kanji -> ../data_cleaned/jouyou_kanji_grayscale
# 100%|██████████| 2136/2136 [00:09<00:00, 223.53it/s]

# %%
# process all kanji
all_kanji_in = '../data_cleaned/kanji_all'
all_kanji_out = '../data_cleaned/all_kanji_grayscale'

convert_svg2png(all_kanji_in, all_kanji_out)
# Out:
# Starting to process ../data_cleaned/kanji_all -> ../data_cleaned/all_kanji_grayscale
# 100%|██████████| 11658/11658 [00:55<00:00, 209.68it/s]
